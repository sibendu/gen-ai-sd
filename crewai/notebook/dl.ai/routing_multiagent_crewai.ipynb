# %%
import os 
from dotenv import load_dotenv
load_dotenv('../../.env')

model=os.environ.get('model')
print(model)

os.environ["AZURE_OPENAI_ENDPOINT"] = os.environ.get('AZURE_API_BASE')
os.environ["AZURE_OPENAI_API_KEY"] = os.environ.get('AZURE_API_KEY')
os.environ["AZURE_OPENAI_API_VERSION"] = os.environ.get('AZURE_API_VERSION')
# Out:
# azure/gpt-4

# %%
from crewai import Agent, Task, Crew, Process
from textwrap import dedent
from typing import List, Dict, Any

# %%
class TravelCrew:
    def __init__(self):
        # Create specialized travel agents
        self.flight_agent = Agent(
            role='Flight Expert',
            goal='Help users with flight-related queries and bookings',
            backstory=dedent("""
                You are an expert in flight bookings and airline operations. 
                You have extensive knowledge of airlines, routes, and booking processes.
            """),
            verbose=True,
            llm=model,
        )

        self.train_agent = Agent(
            role='Train Expert',
            goal='Help users with train-related queries and bookings',
            backstory=dedent("""
                You are an expert in train travel and railway systems.
                You have deep knowledge of train routes, schedules, and booking procedures.
            """),
            verbose=True,
            llm=model,
        )

        self.travel_assistant = Agent(
            role='General Travel Assistant',
            goal='Help with general travel planning and queries',
            backstory=dedent("""
                You are a knowledgeable travel assistant with expertise in 
                various aspects of travel planning including accommodations,
                local transportation, and tourist activities.
            """),
            verbose=True,
            llm=model,
        )

# %%
class FinanceCrew:
    def __init__(self):
        # Create specialized finance agents
        self.stock_agent = Agent(
            role='Stock Market Expert',
            goal='Provide stock market analysis and investment advice',
            backstory=dedent("""
                You are a seasoned stock market analyst with extensive experience
                in equity markets and investment strategies.
            """),
            verbose=True,
            llm=model,
        )

        self.mutual_fund_agent = Agent(
            role='Mutual Fund Expert',
            goal='Provide mutual fund investment advice',
            backstory=dedent("""
                You are an expert in mutual funds with deep knowledge of 
                different fund types, risk assessment, and portfolio management.
            """),
            verbose=True,
            llm=model,
        )

        self.finance_assistant = Agent(
            role='General Finance Assistant',
            goal='Help with general financial queries',
            backstory=dedent("""
                You are a knowledgeable financial advisor who can help with
                basic financial planning and general money management questions.
            """),
            verbose=True,
            llm=model,
        )

# %%
class SupervisorSystem:
    def __init__(self):
        # Initialize specialized crews
        self.travel_crew = TravelCrew()
        self.finance_crew = FinanceCrew()

        # Create supervisor agents
        self.travel_supervisor = Agent(
            role='Travel Supervisor',
            goal='Route and manage travel-related queries',
            backstory=dedent("""
                You are a supervisor responsible for analyzing travel-related queries
                and directing them to the appropriate specialized agent.
            """),
            verbose=True,
            llm=model,
        )

        self.finance_supervisor = Agent(
            role='Finance Supervisor',
            goal='Route and manage finance-related queries',
            backstory=dedent("""
                You are a supervisor responsible for analyzing finance-related queries
                and directing them to the appropriate specialized agent.
            """),
            verbose=True,
            llm=model,
        )

        self.main_supervisor = Agent(
            role='Main Supervisor',
            goal='Route queries to appropriate department',
            backstory=dedent("""
                You are the main supervisor responsible for analyzing incoming queries
                and routing them to either the travel or finance department.
            """),
            verbose=True,
            llm=model,
        )

    def _create_travel_tasks(self, query: str) -> List[Task]:
        # Analyze query to determine specific travel agent
        if "flight" in query.lower() or "airline" in query.lower():
            agent = self.travel_crew.flight_agent
        elif "train" in query.lower() or "railway" in query.lower():
            agent = self.travel_crew.train_agent
        else:
            agent = self.travel_crew.travel_assistant

        return [
            Task(
                description=f"Process travel query: {query}",
                expected_output="A satisfactory resolution of the query",
                agent=agent
            )
        ]

    def _create_finance_tasks(self, query: str) -> List[Task]:
        # Analyze query to determine specific finance agent
        if "stock" in query.lower() or "shares" in query.lower():
            agent = self.finance_crew.stock_agent
        elif "mutual fund" in query.lower() or "mf" in query.lower():
            agent = self.finance_crew.mutual_fund_agent
        else:
            agent = self.finance_crew.finance_assistant

        return [
            Task(
                description=f"Process finance query: {query}",
                expected_output="A satisfactory resolution of the query",
                agent=agent
            )
        ]

    def process_query(self, query: str) -> str:
        # First, determine if query is travel or finance related
        travel_keywords = {"travel", "flight", "train", "hotel", "booking", "trip", "vacation"}
        finance_keywords = {"money", "invest", "stock", "fund", "financial", "market"}
        
        query_lower = query.lower()
        is_travel = any(keyword in query_lower for keyword in travel_keywords)
        is_finance = any(keyword in query_lower for keyword in finance_keywords)

        # Create appropriate tasks based on query type
        if is_travel:
            tasks = self._create_travel_tasks(query)
            supervisor = self.travel_supervisor
        elif is_finance:
            tasks = self._create_finance_tasks(query)
            supervisor = self.finance_supervisor
        else:
            # Default to travel for unclassified queries
            tasks = self._create_travel_tasks(query)
            supervisor = self.travel_supervisor

        # Create crew with appropriate supervisor and tasks
        crew = Crew(
            agents=[supervisor],
            tasks=tasks,
            process=Process.sequential
        )

        # Execute the tasks
        result = crew.kickoff()
        return result

# %%
def main():
    # Initialize the system
    system = SupervisorSystem()

    # Example queries
    example_queries = [
        "I need to book a flight from New York to London",
        "What are the best mutual funds to invest in?",
        "Help me plan a vacation in Europe",
        "Should I invest in tech stocks?",
        "I need a train ticket to Boston"
    ]

    # Process each query
    for query in example_queries:
        print(f"\nProcessing query: {query}")
        result = system.process_query(query)
        print(f"Response: {result}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Processing query: I need to book a flight from New York to London
# # Agent: Flight Expert
# ## Task: Process travel query: I need to book a flight from New York to London
# Overriding of current TracerProvider is not allowed
# # Agent: Flight Expert
# ## Final Answer:
# To book a flight from New York to London, I would need to gather more specific information from you to provide the most complete and satisfactory answer possible. Here are the details I would need:
#
# 1. Your preferred dates of travel for both departure and return, if it's a round trip.
# 2. The number of passengers that will be flying.
# 3. Your preferred airline(s), if any, or if you're looking for the most cost-effective option.
# 4. Your preferred class of service - economy, business, or first class.
# 5. Any specific requirements such as direct flights only, flight timing preferences, or additional services.
#
# Once I have this information, I would be able to look into different airlines that operate between New York and London, such as British Airways, Virgin Atlantic, American Airlines, and Delta Air Lines. I would compare the various flight options considering price, duration, layovers (if acceptable), and any other preferences you have mentioned.
#
# I would then provide a selection of flights that best match your criteria, including detailed information on the flight times, duration, layovers (if any), and prices for each fare class available. I will also inform you about the luggage allowance, cancellation policy, and any COVID-19 related travel restrictions or requirements.
#
# After you've made your flight selection, I would guide you through the booking process which will include providing personal details, selecting seats, meal preferences if applicable, and completing the payment.
#
# Should you wish to proceed with any additional services such as hotel bookings, car rentals, or travel insurance, I would assist with these as well to ensure a smooth and complete travel experience.
#
# To proceed with this booking or if you have any further questions, please provide the required details and any additional requests you may have.
#
#
# Response: To book a flight from New York to London, I would need to gather more specific information from you to provide the most complete and satisfactory answer possible. Here are the details I would need:
#
# 1. Your preferred dates of travel for both departure and return, if it's a round trip.
# 2. The number of passengers that will be flying.
# 3. Your preferred airline(s), if any, or if you're looking for the most cost-effective option.
# 4. Your preferred class of service - economy, business, or first class.
# 5. Any specific requirements such as direct flights only, flight timing preferences, or additional services.
#
# Once I have this information, I would be able to look into different airlines that operate between New York and London, such as British Airways, Virgin Atlantic, American Airlines, and Delta Air Lines. I would compare the various flight options considering price, duration, layovers (if acceptable), and any other preferences you have mentioned.
#
# I would then provide a selection of flights that best match your criteria, including detailed information on the flight times, duration, layovers (if any), and prices for each fare class available. I will also inform you about the luggage allowance, cancellation policy, and any COVID-19 related travel restrictions or requirements.
#
# After you've made your flight selection, I would guide you through the booking process which will include providing personal details, selecting seats, meal preferences if applicable, and completing the payment.
#
# Should you wish to proceed with any additional services such as hotel bookings, car rentals, or travel insurance, I would assist with these as well to ensure a smooth and complete travel experience.
#
# To proceed with this booking or if you have any further questions, please provide the required details and any additional requests you may have.
#
# Processing query: What are the best mutual funds to invest in?
# # Agent: Mutual Fund Expert
# ## Task: Process finance query: What are the best mutual funds to invest in?
# Overriding of current TracerProvider is not allowed
# # Agent: Mutual Fund Expert
# ## Final Answer:
# The term "best" mutual funds can vary depending on individual investment goals, risk tolerance, time horizon, and market conditions at the time of investment. As a mutual fund expert, I can guide you towards understanding the different types of mutual funds and factors to consider when selecting a fund to invest in. However, I cannot specify which mutual funds are currently the best without real-time information and a clear understanding of your specific investment profile.
#
# There are several categories of mutual funds that cater to various investment objectives:
#
# 1. **Index Funds**: These funds aim to replicate the performance of a specific index, such as the S&P 500. They are known for their low expense ratios and are suitable for passive investors.
#
# 2. **Active Funds**: Managed by professional fund managers who actively select securities to outperform the market or a benchmark index. They usually have higher fees than index funds.
#
# 3. **Equity Funds**: Focused on investing in stocks, they can range from large-cap to small-cap funds and may focus on growth or value investing, or a blend of both.
#
# 4. **Fixed Income Funds**: These invest in bonds and other debt instruments and are often favored by investors looking for steady income and lower risk compared to equity funds.
#
# 5. **Balanced Funds**: Also known as hybrid funds, these include both stocks and bonds, aiming to balance the risk and returns.
#
# 6. **Sector or Thematic Funds**: These focus on specific industry sectors or investment themes, offering the potential for higher returns but also higher risk.
#
# 7. **International Funds**: Invest in stocks or bonds outside of the investor's home country, providing diversification and exposure to foreign markets.
#
# To assess the quality of a mutual fund, one should consider several factors:
#
# - **Performance History**: While past performance is not indicative of future results, understanding the fund's historical returns can provide insights into how it performs across different market conditions.
#
# - **Expense Ratio**: The cost of owning the mutual fund, including management fees. Lower expense ratios can significantly impact long-term investment growth.
#
# - **Fund Manager Tenure and Track Record**: The experience and past performance of the fund manager can influence the fund's prospects.
#
# - **Risk Profile**: Consider the fund's volatility and how it aligns with your risk tolerance.
#
# - **Asset Allocation**: Ensure the fund’s portfolio aligns with your investment strategy and diversification goals.
#
# - **Morningstar Ratings**: Some investors look at ratings from research firms like Morningstar as part of their overall evaluation.
#
# I would recommend consulting with a financial advisor or conducting thorough research through financial news platforms, fund prospectuses, and performance reports to determine the mutual funds that best suit your personal investment strategy and objectives. Always consider current market trends, economic forecasts, and ensure your selections align with your financial goals and risk appetite.
#
#
# Response: The term "best" mutual funds can vary depending on individual investment goals, risk tolerance, time horizon, and market conditions at the time of investment. As a mutual fund expert, I can guide you towards understanding the different types of mutual funds and factors to consider when selecting a fund to invest in. However, I cannot specify which mutual funds are currently the best without real-time information and a clear understanding of your specific investment profile.
#
# There are several categories of mutual funds that cater to various investment objectives:
#
# 1. **Index Funds**: These funds aim to replicate the performance of a specific index, such as the S&P 500. They are known for their low expense ratios and are suitable for passive investors.
#
# 2. **Active Funds**: Managed by professional fund managers who actively select securities to outperform the market or a benchmark index. They usually have higher fees than index funds.
#
# 3. **Equity Funds**: Focused on investing in stocks, they can range from large-cap to small-cap funds and may focus on growth or value investing, or a blend of both.
#
# 4. **Fixed Income Funds**: These invest in bonds and other debt instruments and are often favored by investors looking for steady income and lower risk compared to equity funds.
#
# 5. **Balanced Funds**: Also known as hybrid funds, these include both stocks and bonds, aiming to balance the risk and returns.
#
# 6. **Sector or Thematic Funds**: These focus on specific industry sectors or investment themes, offering the potential for higher returns but also higher risk.
#
# 7. **International Funds**: Invest in stocks or bonds outside of the investor's home country, providing diversification and exposure to foreign markets.
#
# To assess the quality of a mutual fund, one should consider several factors:
#
# - **Performance History**: While past performance is not indicative of future results, understanding the fund's historical returns can provide insights into how it performs across different market conditions.
#
# - **Expense Ratio**: The cost of owning the mutual fund, including management fees. Lower expense ratios can significantly impact long-term investment growth.
#
# - **Fund Manager Tenure and Track Record**: The experience and past performance of the fund manager can influence the fund's prospects.
#
# - **Risk Profile**: Consider the fund's volatility and how it aligns with your risk tolerance.
#
# - **Asset Allocation**: Ensure the fund’s portfolio aligns with your investment strategy and diversification goals.
#
# - **Morningstar Ratings**: Some investors look at ratings from research firms like Morningstar as part of their overall evaluation.
#
# I would recommend consulting with a financial advisor or conducting thorough research through financial news platforms, fund prospectuses, and performance reports to determine the mutual funds that best suit your personal investment strategy and objectives. Always consider current market trends, economic forecasts, and ensure your selections align with your financial goals and risk appetite.
#
# Processing query: Help me plan a vacation in Europe
# # Agent: General Travel Assistant
# ## Task: Process travel query: Help me plan a vacation in Europe
# Overriding of current TracerProvider is not allowed
# # Agent: General Travel Assistant
# ## Final Answer:
# To assist you with planning a vacation in Europe, we would need to consider several factors for a comprehensive plan, including destinations, duration, budget, interests, and preferences for accommodations and activities. Here's a general outline to get you started on your European vacation:
#
# 1. **Choosing Destinations:**
#    - Select countries and cities that interest you.
#    - Consider diversity in experiences, from historic cities to natural landscapes.
#    - Decide on a travel route that makes sense logistically.
#
# 2. **Duration:**
#    - Determine how much time you can spend on your vacation.
#    - Allocate enough time in each destination to enjoy without feeling rushed.
#
# 3. **Budget:**
#    - Outline your budget for flights, accommodations, food, activities, and emergencies.
#    - Look for travel deals and consider traveling in the shoulder season for lower prices.
#
# 4. **Accommodations:**
#    - Choose between hotels, hostels, vacation rentals, or bed-and-breakfasts depending on your budget and comfort preference.
#    - Book accommodations well in advance, especially if traveling during peak season or to popular destinations.
#
# 5. **Transportation:**
#    - Investigate flights to Europe and between European destinations.
#    - Look into rail passes like Eurail for cost-effective and convenient travel between cities and countries.
#    - Consider renting a car if you wish to explore rural areas or places with limited public transport.
#
# 6. **Activities and Attractions:**
#    - Research activities and attractions in each destination.
#    - Consider purchasing tickets in advance for popular attractions to avoid long lines.
#    - Mix in a variety of experiences such as guided tours, museums, outdoor adventures, and cultural shows.
#
# 7. **Local Customs and Etiquette:**
#    - Learn a few key phrases in the local languages.
#    - Familiarize yourself with local customs, dining etiquettes, and tipping practices.
#
# 8. **Travel Documentation:**
#    - Ensure your passport is valid for at least 6 months beyond your planned return date.
#    - Check visa requirements for the countries you plan to visit.
#    - Consider travel insurance for unexpected events.
#
# 9. **Packing:**
#    - Create a packing list tailored to the weather and activities planned.
#    - Remember to pack adapters for European electrical outlets and any necessary medication.
#
# 10. **Safety and Health:**
#     - Check health advisories and vaccination requirements.
#     - Register with your embassy if recommended.
#     - Keep a list of emergency contacts and local emergency services.
#
# By taking each of these points into account, you'll create a well-rounded plan for a memorable European vacation. Remember to detail each aspect based on your specific criteria and preferences for the best personalized travel experience. Safe travels!
#
#
# Response: To assist you with planning a vacation in Europe, we would need to consider several factors for a comprehensive plan, including destinations, duration, budget, interests, and preferences for accommodations and activities. Here's a general outline to get you started on your European vacation:
#
# 1. **Choosing Destinations:**
#    - Select countries and cities that interest you.
#    - Consider diversity in experiences, from historic cities to natural landscapes.
#    - Decide on a travel route that makes sense logistically.
#
# 2. **Duration:**
#    - Determine how much time you can spend on your vacation.
#    - Allocate enough time in each destination to enjoy without feeling rushed.
#
# 3. **Budget:**
#    - Outline your budget for flights, accommodations, food, activities, and emergencies.
#    - Look for travel deals and consider traveling in the shoulder season for lower prices.
#
# 4. **Accommodations:**
#    - Choose between hotels, hostels, vacation rentals, or bed-and-breakfasts depending on your budget and comfort preference.
#    - Book accommodations well in advance, especially if traveling during peak season or to popular destinations.
#
# 5. **Transportation:**
#    - Investigate flights to Europe and between European destinations.
#    - Look into rail passes like Eurail for cost-effective and convenient travel between cities and countries.
#    - Consider renting a car if you wish to explore rural areas or places with limited public transport.
#
# 6. **Activities and Attractions:**
#    - Research activities and attractions in each destination.
#    - Consider purchasing tickets in advance for popular attractions to avoid long lines.
#    - Mix in a variety of experiences such as guided tours, museums, outdoor adventures, and cultural shows.
#
# 7. **Local Customs and Etiquette:**
#    - Learn a few key phrases in the local languages.
#    - Familiarize yourself with local customs, dining etiquettes, and tipping practices.
#
# 8. **Travel Documentation:**
#    - Ensure your passport is valid for at least 6 months beyond your planned return date.
#    - Check visa requirements for the countries you plan to visit.
#    - Consider travel insurance for unexpected events.
#
# 9. **Packing:**
#    - Create a packing list tailored to the weather and activities planned.
#    - Remember to pack adapters for European electrical outlets and any necessary medication.
#
# 10. **Safety and Health:**
#     - Check health advisories and vaccination requirements.
#     - Register with your embassy if recommended.
#     - Keep a list of emergency contacts and local emergency services.
#
# By taking each of these points into account, you'll create a well-rounded plan for a memorable European vacation. Remember to detail each aspect based on your specific criteria and preferences for the best personalized travel experience. Safe travels!
#
# Processing query: Should I invest in tech stocks?
# # Agent: Stock Market Expert
# ## Task: Process finance query: Should I invest in tech stocks?
# Overriding of current TracerProvider is not allowed
# # Agent: Stock Market Expert
# ## Final Answer:
# When considering an investment in tech stocks, it's important to assess several key factors. Firstly, evaluate the current market conditions, as tech stocks can be particularly sensitive to market trends and economic indicators. Look at the performance of the tech sector compared to other sectors, and consider whether tech stocks are currently overvalued or undervalued.
#
# Secondly, tech companies' fundamentals should be analyzed, including their earnings, growth potential, financial health, and competitive positioning. Focus on companies with strong balance sheets, sustainable revenue growth, and innovative products or services that can maintain a competitive edge.
#
# Diversification is also crucial when investing in tech stocks. Instead of concentrating your investment on a single stock or subsector, consider spreading it across various companies and technology subsectors (e.g., software, hardware, semiconductors, cloud computing, artificial intelligence, etc.) to manage risk.
#
# Additionally, examine the impact of recent events. For instance, regulatory challenges, data privacy issues, and global trade tensions can affect tech companies differently. Keep an eye on how such events might influence the industry and individual companies.
#
# It is also worth considering the long-term trends that could drive growth in the technology sector, such as the increasing adoption of cloud computing, the roll-out of 5G networks, the expansion of the Internet of Things (IoT), and advancements in artificial intelligence and machine learning. These trends could provide growth opportunities for tech companies over the coming years.
#
# Finally, consider your investment strategy and risk tolerance. Tech stocks can be volatile and might not be suitable for every investor. If you are comfortable with higher risk for the potential of higher returns and have a longer investment horizon, tech stocks might be a suitable addition to your portfolio.
#
# Given these considerations, and without specific investment advice tailored to your individual circumstances, you should conduct thorough research or consult with a financial advisor to determine if and how investing in tech stocks aligns with your financial goals and investment strategy. Remember that past performance is not indicative of future results, and never invest money you cannot afford to lose.
#
#
# Response: When considering an investment in tech stocks, it's important to assess several key factors. Firstly, evaluate the current market conditions, as tech stocks can be particularly sensitive to market trends and economic indicators. Look at the performance of the tech sector compared to other sectors, and consider whether tech stocks are currently overvalued or undervalued.
#
# Secondly, tech companies' fundamentals should be analyzed, including their earnings, growth potential, financial health, and competitive positioning. Focus on companies with strong balance sheets, sustainable revenue growth, and innovative products or services that can maintain a competitive edge.
#
# Diversification is also crucial when investing in tech stocks. Instead of concentrating your investment on a single stock or subsector, consider spreading it across various companies and technology subsectors (e.g., software, hardware, semiconductors, cloud computing, artificial intelligence, etc.) to manage risk.
#
# Additionally, examine the impact of recent events. For instance, regulatory challenges, data privacy issues, and global trade tensions can affect tech companies differently. Keep an eye on how such events might influence the industry and individual companies.
#
# It is also worth considering the long-term trends that could drive growth in the technology sector, such as the increasing adoption of cloud computing, the roll-out of 5G networks, the expansion of the Internet of Things (IoT), and advancements in artificial intelligence and machine learning. These trends could provide growth opportunities for tech companies over the coming years.
#
# Finally, consider your investment strategy and risk tolerance. Tech stocks can be volatile and might not be suitable for every investor. If you are comfortable with higher risk for the potential of higher returns and have a longer investment horizon, tech stocks might be a suitable addition to your portfolio.
#
# Given these considerations, and without specific investment advice tailored to your individual circumstances, you should conduct thorough research or consult with a financial advisor to determine if and how investing in tech stocks aligns with your financial goals and investment strategy. Remember that past performance is not indicative of future results, and never invest money you cannot afford to lose.
#
# Processing query: I need a train ticket to Boston
# # Agent: Train Expert
# ## Task: Process travel query: I need a train ticket to Boston
#
#
# # Agent: Train Expert
# ## Final Answer:
# To purchase a train ticket to Boston, please follow these steps:
#
# 1. Go to the official website of the train service provider in your region or country, such as Amtrak in the United States (www.amtrak.com).
# 2. Use the booking interface on the homepage to enter your starting point and destination. In your case, the destination is Boston.
# 3. Select your desired travel date and time. If you also need a return ticket, make sure to enter the return date as well.
# 4. Choose the class of service you prefer, such as coach, business, or sleeper accommodations if available.
# 5. Indicate the number of passengers and any specific discounts for which you may be eligible (e.g., senior, student, military).
# 6. Click 'Find Trains' or the equivalent button to proceed.
# 7. Review your itinerary options, including departure and arrival times, travel duration, and fares.
# 8. Choose the train that best fits your schedule and budget, and then click on it to continue.
# 9. Provide passenger details as prompted and any additional travel preferences.
# 10. Proceed to the payment section, enter your payment information, and complete your purchase.
# 11. Once your transaction is successful, you will receive a confirmation email with your ticket information. Depending on the provider, you might be able to print your ticket at home, use an e-ticket, or pick up the ticket at a kiosk in the train station.
#
# Remember to check the current travel guidelines and any COVID-19 related restrictions or requirements that may be in place.
#
# For personalized assistance, you can call the customer service number of the train service provider or visit a ticket office in person. Safe travels to Boston!
#
#
# Response: To purchase a train ticket to Boston, please follow these steps:
#
# 1. Go to the official website of the train service provider in your region or country, such as Amtrak in the United States (www.amtrak.com).
# 2. Use the booking interface on the homepage to enter your starting point and destination. In your case, the destination is Boston.
# 3. Select your desired travel date and time. If you also need a return ticket, make sure to enter the return date as well.
# 4. Choose the class of service you prefer, such as coach, business, or sleeper accommodations if available.
# 5. Indicate the number of passengers and any specific discounts for which you may be eligible (e.g., senior, student, military).
# 6. Click 'Find Trains' or the equivalent button to proceed.
# 7. Review your itinerary options, including departure and arrival times, travel duration, and fares.
# 8. Choose the train that best fits your schedule and budget, and then click on it to continue.
# 9. Provide passenger details as prompted and any additional travel preferences.
# 10. Proceed to the payment section, enter your payment information, and complete your purchase.
# 11. Once your transaction is successful, you will receive a confirmation email with your ticket information. Depending on the provider, you might be able to print your ticket at home, use an e-ticket, or pick up the ticket at a kiosk in the train station.
#
# Remember to check the current travel guidelines and any COVID-19 related restrictions or requirements that may be in place.
#
# For personalized assistance, you can call the customer service number of the train service provider or visit a ticket office in person. Safe travels to Boston!
